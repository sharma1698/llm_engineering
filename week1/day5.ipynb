# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import json
from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display
from scraper import fetch_website_links, fetch_website_contents
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")

MODEL = 'gpt-5-nano'
openai = OpenAI()
# MODEL = 'llama3.2:1b'
# openai = OpenAI(base_url='http://localhost:11434/v1',api_key='ollama')
# Out:
# API key looks good so far

# %%
links = fetch_website_links("https://www.canva.in/")
links
# Out:
# ['#mainId',
#  'https://www.canva.com/sheets/',
#  'https://www.canva.com/docs/',
#  'https://www.canva.com/online-whiteboard/',
#  'https://www.canva.com/presentations/',
#  'https://www.canva.com/social-media/',
#  'https://www.canva.com/photo-editor/',
#  'https://www.canva.com/video-editor/',
#  'https://www.canva.com/en_gb/print/',
#  'https://www.canva.com/website-builder/',
#  'https://www.canva.com/pdf-editor/',
#  'https://www.canva.com/en_gb/business-cards/',
#  'https://www.canva.com/en_gb/invitations/',
#  'https://www.canva.com/en_gb/flyers/',
#  'https://www.canva.com/en_gb/brochures/',
#  'https://www.canva.com/en_gb/t-shirts/',
#  'https://www.canva.com/en_gb/custom-mugs/',
#  'https://www.canva.com/en_gb/stickers/',
#  'https://www.canva.com/en_gb/hoodies-sweatshirts/',
#  'https://www.canva.com/en_gb/labels/',
#  'https://www.canva.com/en_gb/posters/',
#  'https://www.canva.com/photo-editor/',
#  'https://www.canva.com/features/background-remover/',
#  'https://www.canva.com/photo-collages/',
#  'https://www.canva.com/mockups/',
#  'https://www.canva.com/features/image-enhancer/',
#  'https://www.canva.com/ai-image-generator/',
#  'https://www.canva.com/features/ai-photo-editing/',
#  'https://www.canva.com/ai-art-generator/',
#  'https://www.canva.com/logos/',
#  'https://www.canva.com/video-editor/',
#  'https://www.canva.com/video-editor/youtube/',
#  'https://www.canva.com/features/video-trimmer/',
#  'https://www.canva.com/features/mp4-converter/',
#  'https://www.canva.com/features/ai-video-generator/',
#  'https://www.canva.com/features/text-to-speech/',
#  'https://www.canva.com/features/ai-music-generator/',
#  'https://www.canva.com/features/ai-voice-generator/',
#  'https://www.canva.com/en_in/launches/',
#  'https://www.canva.com/en_in/visual-suite/',
#  'https://www.canva.com/en_in/solutions/brand-management-tools/',
#  'https://www.canva.com/features/',
#  'https://www.canva.com/en_in/apps/',
#  'https://www.canva.in/templates/',
#  'https://www.canva.com/en_in/magic-layers/',
#  'https://www.canva.com/ai-assistant/',
#  'https://www.canva.com/ai-code-generator/',
#  'https://www.canva.com/en_in/pro/magic-resize/',
#  'https://www.canva.com/en_in/pro/animator/',
#  'https://www.canva.com/magic-write/',
#  'https://www.canva.com/translate/',
#  'https://www.canva.com/features/ai-data-analysis/',
#  'https://www.canva.com/features/ai-formula-generator/',
#  'https://www.canva.com/en_in/canva-ai/',
#  'https://www.canva.com/en_in/pricing/',
#  'https://www.canva.com/en_in/pro/',
#  'https://www.canva.com/en_in/canva-business/',
#  'https://www.canva.com/en_in/enterprise/',
#  'https://www.canva.com/en_in/canva-for-nonprofits/',
#  'https://www.canva.com/en_in/education/',
#  'https://www.canva.com/en_in/for-campus/',
#  'https://www.canva.com/en_in/contact-sales/',
#  'https://www.canva.com/en_in/enterprise/',
#  'https://www.canva.com/en_in/canva-business/',
#  'https://www.canva.com/en_in/business/',
#  'https://www.canva.com/en_in/solutions/marketing/',
#  'https://www.canva.com/en_in/solutions/sales/',
#  'https://www.canva.com/en_in/solutions/it/',
#  'https://www.canva.com/en_in/solutions/creatives/',
#  'https://www.canva.com/en_in/for-campus/',
#  'https://www.canva.com/en_in/solutions/real-estate/',
#  'https://www.canva.com/en_in/solutions/government/',
#  'https://www.canva.com/en_in/solutions/small-business/',
#  'https://www.canva.com/en_in/solutions/',
#  'https://www.canva.com/en_in/solutions/brand-management-tools/',
#  'https://www.canva.com/en_in/solutions/content-creation-tools/',
#  'https://www.canva.com/en_in/business/features/invite-your-team/',
#  'https://www.canva.com/en_in/business/features/security-sso/',
#  'https://www.canva.com/en_in/business/features/apps-integrations/',
#  'https://www.canva.com/en_in/business/features/team-templates/',
#  'https://www.canva.com/en_in/business/features/',
#  'https://www.canva.com/business/case-studies/',
#  'https://www.canva.com/en_in/enterprise/professional-services/',
#  'https://www.canva.com/marketing-ai-report/',
#  'https://www.canva.com/visual-communications-report/',
#  'https://www.canva.com/resources/forrester-tei/',
#  'https://www.canva.com/resources/',
#  'https://www.canva.com/en_in/education/',
#  'https://www.canva.com/en_in/education/students/',
#  'https://www.canva.com/en_in/pricing/#education/',
#  'https://www.canva.com/en_in/education/schools/',
#  'https://www.canva.com/education/features/',
#  'https://www.canva.com/en_in/education/lms-integrations/',
#  'https://www.canva.com/en_in/case-studies/',
#  'https://www.canva.com/en_in/education/contact-sales/',
#  'https://www.canva.com/en_in/education/teachers/',
#  'https://www.canva.com/en_in/education/eligibility-guidelines/',
#  'https://www.canva.com/education/teaching-resources/',
#  'https://www.canva.com/en_in/community/teachers/',
#  'https://www.canva.com/en_in/for-campus/',
#  'https://www.canva.com/en_in/case-studies/',
#  'https://www.canva.com/en_gb/education/contact-sales/',
#  'https://www.canva.com/en_in/for-campus/academic-success/',
#  'https://www.canva.com/en_in/for-campus/accessibility-inclusion/',
#  'https://www.canva.com/en_in/for-campus/brand-management/',
#  'https://www.canva.com/en_in/for-campus/security-sso/',
#  'https://www.canva.com/en_in/help/',
#  'https://www.canva.com/design-school/',
#  'https://www.canva.in/',
#  'https://www.canva.com/en_in/signup/',
#  'https://www.canva.com/en_in/login/',
#  'https://www.canva.com/signup/',
#  'https://www.canva.com/features/photo-background-changer/',
#  'https://www.canva.com/ai-logo-generator/',
#  'https://www.canva.com/features/ai-photo-editing/',
#  'https://www.canva.com/features/ai-voice-generator/',
#  'https://www.canva.com/features/image-enhancer/',
#  'https://www.canva.com/magic-write/',
#  'https://www.canva.com/signup/',
#  '/templates/',
#  '#_R_195bH1_1',
#  '#_R_195bH1_0',
#  'https://www.canva.com/contact-sales/',
#  'https://www.canva.com/en_in/pro/brand-kit/',
#  'https://www.canva.com/en_in/business/features/invite-your-team/',
#  'https://www.canva.com/en_in/pricing/',
#  'https://www.canva.com/en_in/security/',
#  'https://www.canva.com/en_in/education/',
#  'https://www.canva.com/en_in/canva-for-nonprofits/',
#  'https://www.canva.com/en_in/pricing/',
#  '#_R_5rH1_',
#  'https://www.canva.com/en_in/launches/',
#  'https://www.canva.com/en_in/visual-suite/',
#  'https://www.canva.com/en_in/canva-ai/',
#  'https://www.canva.com/en_in/solutions/brand-management-tools/',
#  'https://www.canva.com/social-media/',
#  'https://www.canva.com/features/',
#  'https://www.canva.com/en_gb/print/',
#  'https://www.affinity.studio/',
#  'https://www.canva.in/templates/',
#  'https://www.canva.com/design-trends/',
#  'https://www.canva.com/en_in/pricing/',
#  'https://www.canva.com/en_in/pro/',
#  'https://www.canva.com/en_in/canva-business/',
#  'https://www.canva.com/en_in/enterprise/',
#  'https://www.canva.com/en_in/education/',
#  'https://www.canva.com/en_in/for-campus/',
#  'https://www.canva.com/en_in/canva-for-nonprofits/',
#  'https://www.canva.com/en_in/contact-sales/',
#  'https://www.canva.com/about/',
#  'https://www.canva.com/en_in/newsroom/news/',
#  'https://www.canva.com/events/',
#  'https://www.canva.com/originals/',
#  'https://www.lifeatcanva.com/en',
#  'https://www.canva.com/en_in/step-two/',
#  'https://www.canva.com/en_in/sustainability/',
#  'https://www.canva.com/en_in/case-studies/',
#  'https://www.canva.com/en_in/community/',
#  'https://www.canva.com/en_in/creators/',
#  'https://www.canva.com/en_in/help/canva-affiliate-marketing-program/',
#  'https://www.canva.com/canva-represents/',
#  'https://www.canva.com/partners/content/',
#  'https://partners.canva.com/directory/',
#  'https://www.canva.com/developers/',
#  'https://www.canva.com/design-trends/',
#  'https://promptedpodcast.com/',
#  'https://www.canva.com/learn/',
#  'https://www.canva.in/templates/',
#  'https://www.canva.com/learn/the-ultimate-guide-to-font-pairing/',
#  'https://www.canva.com/colors/color-wheel/',
#  'https://www.canva.com/colors/',
#  'https://www.canva.com/colors/color-palette-generator/',
#  'https://www.canva.com/en_in/help/',
#  'https://www.canva.com/en_in/security/',
#  'https://www.canva.com/en_in/trust/',
#  'https://www.canva.com/en_in/safe-ai-canva-shield/',
#  'https://www.canva.com/accessibility/',
#  'https://www.canva.com/en_in/enterprise/professional-services/',
#  'https://www.canva.com/design-school/',
#  'https://www.canva.com/en_in/sitemap/',
#  'https://www.canva.com/en_in/launches/',
#  'https://www.canva.com/en_in/visual-suite/',
#  'https://www.canva.com/en_in/canva-ai/',
#  'https://www.canva.com/en_in/solutions/brand-management-tools/',
#  'https://www.canva.com/social-media/',
#  'https://www.canva.com/features/',
#  'https://www.canva.com/en_gb/print/',
#  'https://www.affinity.studio/',
#  'https://www.canva.in/templates/',
#  'https://www.canva.com/design-trends/',
#  'https://www.canva.com/en_in/pricing/',
#  'https://www.canva.com/en_in/pro/',
#  'https://www.canva.com/en_in/canva-business/',
#  'https://www.canva.com/en_in/enterprise/',
#  'https://www.canva.com/en_in/education/',
#  'https://www.canva.com/en_in/for-campus/',
#  'https://www.canva.com/en_in/canva-for-nonprofits/',
#  'https://www.canva.com/en_in/contact-sales/',
#  'https://www.canva.com/about/',
#  'https://www.canva.com/en_in/newsroom/news/',
#  'https://www.canva.com/events/',
#  'https://www.canva.com/originals/',
#  'https://www.lifeatcanva.com/en',
#  'https://www.canva.com/en_in/step-two/',
#  'https://www.canva.com/en_in/sustainability/',
#  'https://www.canva.com/en_in/case-studies/',
#  'https://www.canva.com/en_in/community/',
#  'https://www.canva.com/en_in/creators/',
#  'https://www.canva.com/en_in/help/canva-affiliate-marketing-program/',
#  'https://www.canva.com/canva-represents/',
#  'https://www.canva.com/partners/content/',
#  'https://partners.canva.com/directory/',
#  'https://www.canva.com/developers/',
#  'https://www.canva.com/design-trends/',
#  'https://promptedpodcast.com/',
#  'https://www.canva.com/learn/',
#  'https://www.canva.in/templates/',
#  'https://www.canva.com/learn/the-ultimate-guide-to-font-pairing/',
#  'https://www.canva.com/colors/color-wheel/',
#  'https://www.canva.com/colors/',
#  'https://www.canva.com/colors/color-palette-generator/',
#  'https://www.canva.com/en_in/help/',
#  'https://www.canva.com/en_in/security/',
#  'https://www.canva.com/en_in/trust/',
#  'https://www.canva.com/en_in/safe-ai-canva-shield/',
#  'https://www.canva.com/accessibility/',
#  'https://www.canva.com/en_in/enterprise/professional-services/',
#  'https://www.canva.com/design-school/',
#  'https://www.canva.com/en_in/sitemap/',
#  'https://www.canva.com/af_za/',
#  'https://www.canva.com/sq_al/',
#  'https://www.canva.com/am_et/',
#  'https://www.canva.com/ar/',
#  'https://www.canva.com/ar_eg/',
#  'https://www.canva.com/ar_sa/',
#  'https://www.canva.com/ar_ae/',
#  'https://www.canva.com/hy_am/',
#  'https://www.canva.com/as_in/',
#  'https://www.canva.com/az_az/',
#  'https://www.canva.com/bn_bd/',
#  'https://www.canva.com/eu_es/',
#  'https://www.canva.com/bg_bg/',
#  'https://www.canva.com/my_mm/',
#  'https://www.canva.com/ca_es/',
#  'https://www.canva.com/ceb_ph/',
#  'https://www.canva.com/zh_cn/',
#  'https://www.canva.com/zh_hk/',
#  'https://www.canva.com/zh_tw/',
#  'https://www.canva.com/hr_hr/',
#  'https://www.canva.com/cs_cz/',
#  'https://www.canva.com/da_dk/',
#  'https://www.canva.com/nl_be/',
#  'https://www.canva.com/nl_nl/',
#  'https://www.canva.com/en/',
#  'https://www.canva.com/en_au/',
#  '/',
#  'https://www.canva.com/en_ph/',
#  'https://www.canva.com/en_gb/',
#  'https://www.canva.com/et_ee/',
#  'https://www.canva.com/fi_fi/',
#  'https://www.canva.com/fr_be/',
#  'https://www.canva.com/fr_ca/',
#  'https://www.canva.com/fr_fr/',
#  'https://www.canva.com/ff_sn/',
#  'https://www.canva.com/gl_es/',
#  'https://www.canva.com/ka_ge/',
#  'https://www.canva.com/de_de/',
#  'https://www.canva.com/el_gr/',
#  'https://www.canva.com/gu_in/',
#  'https://www.canva.com/ha_ng/',
#  'https://www.canva.com/he_il/',
#  'https://www.canva.com/hi_in/',
#  'https://www.canva.com/hu_hu/',
#  'https://www.canva.com/ig_ng/',
#  'https://www.canva.com/id_id/',
#  'https://www.canva.com/it_it/',
#  'https://www.canva.com/ja_jp/',
#  'https://www.canva.com/jv_id/',
#  'https://www.canva.com/kn_in/',
#  'https://www.canva.com/kk_kz/',
#  'https://www.canva.com/km_kh/',
#  'https://www.canva.com/ko_kr/',
#  'https://www.canva.com/ku_tr/',
#  'https://www.canva.com/ky_kg/',
#  'https://www.canva.com/lv_lv/',
#  'https://www.canva.com/lt_lt/',
#  'https://www.canva.com/ma_in/',
#  'https://www.canva.com/mk_mk/',
#  'https://www.canva.com/mg_mg/',
#  'https://www.canva.com/ms_my/',
#  'https://www.canva.com/ml_in/',
#  'https://www.canva.com/mr_in/',
#  'https://www.canva.com/mn_mn/',
#  'https://www.canva.com/ne_np/',
#  'https://www.canva.com/nb_no/',
#  'https://www.canva.com/ny_mw/',
#  'https://www.canva.com/om_et/',
#  'https://www.canva.com/fa_ir/',
#  'https://www.canva.com/pl_pl/',
#  'https://www.canva.com/pt_br/',
#  'https://www.canva.com/pt_pt/',
#  'https://www.canva.com/pa_in/',
#  'https://www.canva.com/pa_pk/',
#  'https://www.canva.com/ro_ro/',
#  'https://www.canva.com/ru_ru/',
#  'https://www.canva.com/sr_rs/',
#  'https://www.canva.com/sn_zw/',
#  'https://www.canva.com/sd_in/',
#  'https://www.canva.com/si_lk/',
#  'https://www.canva.com/sk_sk/',
#  'https://www.canva.com/sl_si/',
#  'https://www.canva.com/so_so/',
#  'https://www.canva.com/nr_za/',
#  'https://www.canva.com/st_za/',
#  'https://www.canva.com/es_ar/',
#  'https://www.canva.com/es_co/',
#  'https://www.canva.com/es_419/',
#  'https://www.canva.com/es_mx/',
#  'https://www.canva.com/es_es/',
#  'https://www.canva.com/es_us/',
#  'https://www.canva.com/su_id/',
#  'https://www.canva.com/sw_ke/',
#  'https://www.canva.com/ss_za/',
#  'https://www.canva.com/sv_se/',
#  'https://www.canva.com/tl_ph/',
#  'https://www.canva.com/ta_in/',
#  'https://www.canva.com/te_in/',
#  'https://www.canva.com/th_th/',
#  'https://www.canva.com/tr_tr/',
#  'https://www.canva.com/tw_gh/',
#  'https://www.canva.com/uk_ua/',
#  'https://www.canva.com/ur_pk/',
#  'https://www.canva.com/uz_uz/',
#  'https://www.canva.com/vi_vn/',
#  'https://www.canva.com/cy_gb/',
#  'https://www.canva.com/wo_sn/',
#  'https://www.canva.com/xh_za/',
#  'https://www.canva.com/yo_ng/',
#  'https://www.canva.com/zu_za/',
#  '#_R_5r_']

# %% [markdown]
# ## First step: Have GPT-5-nano figure out which links are relevant
#
# ### Use a call to gpt-5-nano to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = """
You are provided with a list of links found on a webpage.
You are able to decide which of the links would be most relevant to include in a brochure about the company,
such as links to an About page, or a Company page, or Careers/Jobs pages.
You should respond in JSON as in this example:

{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page", "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
def get_links_user_prompt(url):
    user_prompt = f"""
Here is the list of links on the website {url} -
Please decide which of these are relevant web links for a brochure about the company,
respond with the full https URL in JSON format.
Do not include Terms of Service, Privacy, email links.

Links (some might be relative links):

"""
    links = fetch_website_links(url)
    user_prompt += "\n".join(links)
    return user_prompt

# %%
print(get_links_user_prompt("https://edwarddonner.com"))
# Out:
# Here is the list of links on the website https://edwarddonner.com -
# Please decide which of these are relevant web links for a brochure about the company,
# respond with the full https URL in JSON format.
# Do not include Terms of Service, Privacy, email links.
#
# Links (some might be relative links):
#
# #wp--skip-link--target
# https://edwarddonner.com/avatar/
# https://edwarddonner.com/curriculum/
# https://edwarddonner.com/proficient/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://edwarddonner.com/curriculum/
# https://edwarddonner.com/avatar/
# https://edwarddonner.com/2026/02/17/ai-coder-vibe-coder-to-agentic-engineer/
# https://edwarddonner.com/2026/02/17/ai-coder-vibe-coder-to-agentic-engineer/
# https://edwarddonner.com/2026/01/04/ai-builder-with-n8n-create-agents-and-voice-agents/
# https://edwarddonner.com/2026/01/04/ai-builder-with-n8n-create-agents-and-voice-agents/
# https://edwarddonner.com/2025/09/15/ai-in-production-gen-ai-and-agentic-ai-on-aws-at-scale/
# https://edwarddonner.com/2025/09/15/ai-in-production-gen-ai-and-agentic-ai-on-aws-at-scale/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/avatar/
# https://edwarddonner.com/curriculum/
# https://edwarddonner.com/proficient/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def select_relevant_links(url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(url)}
        ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    links = json.loads(result)
    return links

# %%
select_relevant_links("https://edwarddonner.com")
# Out:
# {'links': [{'type': 'about me/about-us',
#    'url': 'https://edwarddonner.com/about-me-and-about-nebula'},
#   {'type': 'news', 'url': 'https://news.ycombinator.com'}]}

# %%
def select_relevant_links(url):
    print(f"Selecting relevant links for {url} by calling {MODEL}")
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(url)}
        ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    links = json.loads(result)
    print(f"Found {len(links['links'])} relevant links")
    return links

# %%
select_relevant_links("https://edwarddonner.com")
# Out:
# Selecting relevant links for https://edwarddonner.com by calling llama3.2:1b
# Found 1 relevant links
# {'links': [{'type': 'about page',
#    'url': 'https://edwarddonner.com/about-me-and-about-nebula/'}]}

# %%
select_relevant_links("https://huggingface.co")
# Out:
# Selecting relevant links for https://huggingface.co by calling llama3.2:1b
# Found 4 relevant links
# {'links': [{'type': 'enterprise', 'url': 'https://huggingface.co'},
#   {'type': 'pricing#spaces', 'url': ''},
#   {'type': 'pricing#endpoints', 'url': '@endpoints.huggingface.co'},
#   {'type': 'pronotional-branding', 'url': 'https://brand.huggingface.co'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT-5-nano

# %%
def fetch_page_and_all_relevant_links(url):
    contents = fetch_website_contents(url)
    relevant_links = select_relevant_links(url)
    result = f"## Landing Page:\n\n{contents}\n## Relevant Links:\n"
    for link in relevant_links['links']:
        result += f"\n\n### Link: {link['type']}\n"
        result += fetch_website_contents(link["url"])
    return result

# %%
print(fetch_page_and_all_relevant_links("https://huggingface.co/"))
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages\urllib3\connection.py:204, in HTTPConnection._new_conn(self)
#     203 try:
# --> 204     sock = connection.create_connection(
#     205         (self._dns_host, self.port),
#     206         self.timeout,
#     207         source_address=self.source_address,
#     208         socket_options=self.socket_options,
#     209     )
#     210 except socket.gaierror as e:
#
# File c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\socket.py:977, in getaddrinfo(host, port, family, type, proto, flags)
#     976 addrlist = []
# --> 977 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     978     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# The above exception was the direct cause of the following exception:
#
# NameResolutionError                       Traceback (most recent call last)
# File c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages\urllib3\connectionpool.py:788, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 # Make the request on the HTTPConnection object
# --> 788 response = self._make_request(
#     789     conn,
#     790     method,
#     791     url,
#     792     timeout=timeout_obj,
#     793     body=body,
#     794     headers=headers,
#     795     chunked=chunked,
#     796     retries=retries,
#     797     response_conn=response_conn,
#     798     preload_content=preload_content,
#     799     decode_content=decode_content,
#     800     **response_kw,
#     801 )
#     803 # Everything went great!
#
# File c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages\urllib3\connectionpool.py:488, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     487         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 488     raise new_e
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages\urllib3\connectionpool.py:1106, in HTTPSConnectionPool._validate_conn(self, conn)
#    1105 if conn.is_closed:
# -> 1106     conn.connect()
#    1108 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages\urllib3\connection.py:759, in HTTPSConnection.connect(self)
#     758 sock: socket.socket | ssl.SSLSocket
# --> 759 self.sock = sock = self._new_conn()
#     760 server_hostname: str = self.host
#
# File c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages\urllib3\connection.py:211, in HTTPConnection._new_conn(self)
#     210 except socket.gaierror as e:
# --> 211     raise NameResolutionError(self.host, self, e) from e
#     212 except SocketTimeout as e:
#
# NameResolutionError: HTTPSConnection(host='full.url', port=443): Failed to resolve 'full.url' ([Errno 11001] getaddrinfo failed)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages\requests\adapters.py:696, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     695 try:
# --> 696     resp = conn.urlopen(
#     697         method=request.method,
#     698         url=url,
#     699         body=request.body,  # type: ignore[arg-type]  # urllib3 stubs don't accept Iterable[bytes | str]
#     700         headers=request.headers,  # type: ignore[arg-type]  # urllib3#3072
#     701         redirect=False,
#     702         assert_same_host=False,
#     703         preload_content=False,
#     704         decode_content=False,
#     705         retries=self.max_retries,
#     706         timeout=resolved_timeout,
#     707         chunked=chunked,
#     708     )
#     710 except (ProtocolError, OSError) as err:
#
# File c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages\urllib3\connectionpool.py:842, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     840     new_e = ProtocolError("Connection aborted.", new_e)
# --> 842 retries = retries.increment(
#     843     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     844 )
#     845 retries.sleep()
#
# File c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages\urllib3\util\retry.py:543, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     542     reason = error or ResponseError(cause)
# --> 543     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     545 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='full.url', port=443): Max retries exceeded with url: /goes/here/about (Caused by NameResolutionError("HTTPSConnection(host='full.url', port=443): Failed to resolve 'full.url' ([Errno 11001] getaddrinfo failed)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(fetch_page_and_all_relevant_links("https://huggingface.co/"))
#
# Cell In[9], line 7, in fetch_page_and_all_relevant_links(url)
#       3     relevant_links = select_relevant_links(url)
#       4     result = f"## Landing Page:\n\n{contents}\n## Relevant Links:\n"
#       5     for link in relevant_links['links']:
#       6         result += f"\n\n### Link: {link['type']}\n"
# ----> 7         result += fetch_website_contents(link["url"])
#       8     return result
#
# File c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\week1\scraper.py:16, in fetch_website_contents(url)
#      11 def fetch_website_contents(url):
#      12     """
#      13     Return the title and contents of the website at the given url;
#      14     truncate to 2,000 characters as a sensible limit
#      15     """
# ---> 16     response = requests.get(url, headers=headers)
#      17     soup = BeautifulSoup(response.content, "html.parser")
#      18     title = soup.title.string if soup.title else "No title found"
#
# File c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages\requests\api.py:87, in get(url, params, **kwargs)
#      74 def get(
#      75     url: _t.UriType, params: _t.ParamsType = None, **kwargs: Unpack[_t.GetKwargs]
#      76 ) -> Response:
#      77     r"""Sends a GET request.
#      78
#      79     :param url: URL for the new :class:`Request` object.
#    (...)     84     :rtype: requests.Response
#      85     """
# ---> 87     return request("get", url, params=params, **kwargs)
#
# File c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages\requests\api.py:71, in request(method, url, **kwargs)
#      67 # By using the 'with' statement we are sure the session is closed, thus we
#      68 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      69 # cases, and look like a memory leak in others.
#      70 with sessions.Session() as session:
# ---> 71     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages\requests\sessions.py:651, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     646 send_kwargs = {
#     647     "timeout": timeout,
#     648     "allow_redirects": allow_redirects,
#     649 }
#     650 send_kwargs.update(settings)
# --> 651 resp = self.send(prep, **send_kwargs)
#     653 return resp
#
# File c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages\requests\sessions.py:784, in Session.send(self, request, **kwargs)
#     781 start = preferred_clock()
#     783 # Send the request
# --> 784 r = adapter.send(request, **kwargs)
#     786 # Total elapsed time of the request (approximately)
#     787 elapsed = preferred_clock() - start
#
# File c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages\requests\adapters.py:729, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     725     if isinstance(e.reason, _SSLError):
#     726         # This branch is for urllib3 v1.22 and later.
#     727         raise SSLError(e, request=request)
# --> 729     raise ConnectionError(e, request=request)
#     731 except ClosedPoolError as e:
#     732     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='full.url', port=443): Max retries exceeded with url: /goes/here/about (Caused by NameResolutionError("HTTPSConnection(host='full.url', port=443): Failed to resolve 'full.url' ([Errno 11001] getaddrinfo failed)"))

# %%
brochure_system_prompt = """
You are an assistant that analyzes the contents of several relevant pages from a company website
and creates a short brochure about the company for prospective customers, investors and recruits.
Respond in markdown without code blocks.
Include details of company culture, customers and careers/jobs if you have the information.
"""

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':
# brochure_system_prompt = """
# You are an assistant that analyzes the contents of several relevant pages from a company website
# and creates a short, humorous, entertaining, witty brochure about the company for prospective customers, investors and recruits.
# Respond in markdown without code blocks.
# Include details of company culture, customers and careers/jobs if you have the information.
# """

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"""
You are looking at a company called: {company_name}
Here are the contents of its landing page and other relevant pages;
use this information to build a short brochure of the company in markdown without code blocks.\n\n
"""
    user_prompt += fetch_page_and_all_relevant_links(url)
    user_prompt = user_prompt[:1_000] # Truncate if more than 5,000 characters
    return display(Markdown(user_prompt))

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co/")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 get_brochure_user_prompt("HuggingFace", "https://huggingface.co/")
#
# NameError: name 'get_brochure_user_prompt' is not defined

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model="gpt-4.1-mini",
        messages=[
            {"role": "system", "content": brochure_system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
        ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.co")

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model="gpt-4.1-mini",
        messages=[
            {"role": "system", "content": brochure_system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("HuggingFace", "https://huggingface.co")

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype. See what other students have done in the community-contributions folder -- so many valuable projects -- it's wild!</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 3 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!<br/>
#             3. I'm trying out X/Twitter and I'm at <a href="https://x.com/edwarddonner">@edwarddonner<a> and hoping people will teach me how it's done..
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>
