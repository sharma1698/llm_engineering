# %% [markdown]
# # Gradio Day!
#
# Today we will build User Interfaces using the outrageously simple Gradio framework.
#
# Prepare for joy!
#
# Please note: your Gradio screens may appear in 'dark mode' or 'light mode' depending on your computer settings.

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

# %%
# %pip install --upgrade ipywidgets jupyter
# Out:
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Collecting jupyter
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: comm>=0.1.3 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from ipywidgets) (9.15.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from ipywidgets) (5.15.1)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Collecting notebook (from jupyter)
#   Downloading notebook-7.6.0-py3-none-any.whl.metadata (10 kB)
# Collecting jupyter-console (from jupyter)
#   Downloading jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Collecting nbconvert (from jupyter)
#   Downloading nbconvert-7.17.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: ipykernel in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from jupyter) (7.3.0)
# Collecting jupyterlab (from jupyter)
#   Downloading jupyterlab-4.6.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: colorama>=0.4.4 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: psutil>=7 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.8.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from jedi>=0.18.2->ipython>=6.1.0->ipywidgets) (0.8.7)
# Requirement already satisfied: executing>=1.2.0 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from ipykernel->jupyter) (1.8.21)
# Requirement already satisfied: jupyter-client>=8.9.0 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from ipykernel->jupyter) (8.9.1)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from ipykernel->jupyter) (5.9.1)
# Requirement already satisfied: nest-asyncio2>=1.7.0 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from ipykernel->jupyter) (1.7.2)
# Requirement already satisfied: packaging>=22 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from ipykernel->jupyter) (26.2)
# Requirement already satisfied: pyzmq>=25 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from ipykernel->jupyter) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from ipykernel->jupyter) (6.5.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from jupyter-client>=8.9.0->ipykernel->jupyter) (2.9.0.post0)
# Requirement already satisfied: typing-extensions>=4.13.0 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from jupyter-client>=8.9.0->ipykernel->jupyter) (4.16.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel->jupyter) (4.10.0)
# Requirement already satisfied: six>=1.5 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.9.0->ipykernel->jupyter) (1.17.0)
# Collecting async-lru>=1.0.0 (from jupyterlab->jupyter)
#   Downloading async_lru-2.3.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from jupyterlab->jupyter) (3.1.6)
# Collecting jupyter-builder>=1.0.2 (from jupyterlab->jupyter)
#   Downloading jupyter_builder-1.0.2-py3-none-any.whl.metadata (7.7 kB)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab->jupyter)
#   Downloading jupyter_lsp-2.3.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting jupyter-server<3,>=2.19.0 (from jupyterlab->jupyter)
#   Downloading jupyter_server-2.20.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting jupyterlab-server<3,>=2.28.0 (from jupyterlab->jupyter)
#   Downloading jupyterlab_server-2.28.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting notebook-shim>=0.2 (from jupyterlab->jupyter)
#   Downloading notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: anyio in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (4.14.1)
# Requirement already satisfied: certifi in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: idna in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Collecting argon2-cffi>=21.1 (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter)
#   Downloading argon2_cffi-25.1.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting jupyter-events>=0.11.0 (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter)
#   Downloading jupyter_events-0.12.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter)
#   Downloading jupyter_server_terminals-0.5.4-py3-none-any.whl.metadata (5.9 kB)
# Collecting nbformat>=5.3.0 (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter)
#   Downloading nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Collecting prometheus-client>=0.9 (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter)
#   Downloading prometheus_client-0.25.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting pywinpty!=3.0.4,>=2.0.1 (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter)
#   Downloading pywinpty-3.0.5-cp313-cp313-win_amd64.whl.metadata (5.9 kB)
# Collecting send2trash>=1.8.2 (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter)
#   Downloading send2trash-2.1.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting terminado>=0.8.3 (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter)
#   Downloading terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting websocket-client>=1.7 (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter)
#   Downloading websocket_client-1.9.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting babel>=2.10 (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter)
#   Downloading babel-2.18.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter)
#   Downloading json5-0.15.0-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (4.26.0)
# Requirement already satisfied: requests>=2.31 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.34.2)
# Collecting argon2-cffi-bindings (from argon2-cffi>=21.1->jupyter-server<3,>=2.19.0->jupyterlab->jupyter)
#   Downloading argon2_cffi_bindings-25.1.0-cp39-abi3-win_amd64.whl.metadata (7.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from jinja2>=3.0.3->jupyterlab->jupyter) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2026.6.3)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter)
#   Downloading python_json_logger-4.1.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: pyyaml>=5.3 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (6.0.3)
# Collecting rfc3339-validator (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter)
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (3.1.1)
# Collecting rfc3987-syntax>=1.1.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter)
#   Downloading rfc3987_syntax-1.1.0-py3-none-any.whl.metadata (7.7 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter)
#   Downloading webcolors-25.10.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: beautifulsoup4 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from nbconvert->jupyter) (4.15.0)
# Collecting bleach!=5.0.0 (from bleach[css]!=5.0.0->nbconvert->jupyter)
#   Downloading bleach-6.4.0-py3-none-any.whl.metadata (32 kB)
# Collecting defusedxml (from nbconvert->jupyter)
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting jupyterlab-pygments (from nbconvert->jupyter)
#   Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting mistune<4,>=2.0.3 (from nbconvert->jupyter)
#   Downloading mistune-3.3.2-py3-none-any.whl.metadata (1.9 kB)
# Collecting nbclient>=0.5.0 (from nbconvert->jupyter)
#   Downloading nbclient-0.11.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert->jupyter)
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting webencodings (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter)
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting tinycss2>=1.1.0 (from bleach[css]!=5.0.0->nbconvert->jupyter)
#   Downloading tinycss2-1.5.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting fastjsonschema>=2.15 (from nbformat>=5.3.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter)
#   Downloading fastjsonschema-2.21.2-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.7.0)
# Collecting lark>=1.2.2 (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter)
#   Downloading lark-1.3.1-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: cffi>=1.0.1 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (2.1.0)
# Requirement already satisfied: pycparser in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.8.4)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter)
#   Downloading arrow-1.4.0-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: tzdata in c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (2026.2)
# Downloading ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
#    ---------------------------------------- 0.0/914.9 kB ? eta -:--:--
#    ---------------------------------------- 914.9/914.9 kB 9.7 MB/s  0:00:00
# Downloading widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    -------------------------------------- - 2.1/2.2 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 10.2 MB/s  0:00:00
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Downloading jupyterlab-4.6.1-py3-none-any.whl (17.2 MB)
#    ---------------------------------------- 0.0/17.2 MB ? eta -:--:--
#    ---- ----------------------------------- 2.1/17.2 MB 11.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.7/17.2 MB 11.3 MB/s eta 0:00:02
#    --------------- ------------------------ 6.8/17.2 MB 11.1 MB/s eta 0:00:01
#    --------------------- ------------------ 9.2/17.2 MB 11.3 MB/s eta 0:00:01
#    -------------------------- ------------- 11.5/17.2 MB 11.4 MB/s eta 0:00:01
#    -------------------------------- ------- 13.9/17.2 MB 11.3 MB/s eta 0:00:01
#    ------------------------------------- -- 16.3/17.2 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 17.2/17.2 MB 10.9 MB/s  0:00:01
# Downloading jupyter_server-2.20.0-py3-none-any.whl (393 kB)
# Downloading jupyterlab_server-2.28.0-py3-none-any.whl (59 kB)
# Downloading argon2_cffi-25.1.0-py3-none-any.whl (14 kB)
# Downloading async_lru-2.3.0-py3-none-any.whl (8.4 kB)
# Downloading babel-2.18.0-py3-none-any.whl (10.2 MB)
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    --------- ------------------------------ 2.4/10.2 MB 11.5 MB/s eta 0:00:01
#    ------------------ --------------------- 4.7/10.2 MB 11.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.3/10.2 MB 11.7 MB/s eta 0:00:01
#    -------------------------------------- - 9.7/10.2 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 10.2/10.2 MB 11.3 MB/s  0:00:00
# Downloading json5-0.15.0-py3-none-any.whl (36 kB)
# Downloading jupyter_builder-1.0.2-py3-none-any.whl (910 kB)
#    ---------------------------------------- 0.0/910.8 kB ? eta -:--:--
#    ---------------------------------------- 910.8/910.8 kB 9.3 MB/s  0:00:00
# Downloading jupyter_events-0.12.1-py3-none-any.whl (19 kB)
# Downloading jupyter_lsp-2.3.1-py3-none-any.whl (77 kB)
# Downloading jupyter_server_terminals-0.5.4-py3-none-any.whl (13 kB)
# Downloading nbconvert-7.17.1-py3-none-any.whl (261 kB)
# Downloading mistune-3.3.2-py3-none-any.whl (61 kB)
# Downloading bleach-6.4.0-py3-none-any.whl (165 kB)
# Downloading nbclient-0.11.0-py3-none-any.whl (25 kB)
# Downloading nbformat-5.10.4-py3-none-any.whl (78 kB)
# Downloading fastjsonschema-2.21.2-py3-none-any.whl (24 kB)
# Downloading notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Downloading prometheus_client-0.25.0-py3-none-any.whl (64 kB)
# Downloading python_json_logger-4.1.0-py3-none-any.whl (15 kB)
# Downloading pywinpty-3.0.5-cp313-cp313-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 10.5 MB/s  0:00:00
# Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Downloading rfc3987_syntax-1.1.0-py3-none-any.whl (8.0 kB)
# Downloading lark-1.3.1-py3-none-any.whl (113 kB)
# Downloading send2trash-2.1.0-py3-none-any.whl (17 kB)
# Downloading terminado-0.18.1-py3-none-any.whl (14 kB)
# Downloading tinycss2-1.5.1-py3-none-any.whl (28 kB)
# Downloading webcolors-25.10.0-py3-none-any.whl (14 kB)
# Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Downloading websocket_client-1.9.0-py3-none-any.whl (82 kB)
# Downloading argon2_cffi_bindings-25.1.0-cp39-abi3-win_amd64.whl (31 kB)
# Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading arrow-1.4.0-py3-none-any.whl (68 kB)
# Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Downloading notebook-7.6.0-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    ----------------- ---------------------- 2.4/5.5 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 4.7/5.5 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 11.0 MB/s  0:00:00
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Installing collected packages: webencodings, fastjsonschema, widgetsnbextension, websocket-client, webcolors, uri-template, tinycss2, send2trash, rfc3986-validator, rfc3339-validator, pywinpty, python-json-logger, prometheus-client, pandocfilters, mistune, lark, jupyterlab_widgets, jupyterlab-pygments, json5, fqdn, defusedxml, bleach, babel, async-lru, terminado, rfc3987-syntax, jupyter-builder, arrow, argon2-cffi-bindings, jupyter-server-terminals, isoduration, ipywidgets, argon2-cffi, nbformat, jupyter-console, nbclient, jupyter-events, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, jupyter
#
#     ---------------------------------------  1/45 [fastjsonschema]
#     ---------------------------------------  1/45 [fastjsonschema]
#    - --------------------------------------  2/45 [widgetsnbextension]
#    -- -------------------------------------  3/45 [websocket-client]
#    -- -------------------------------------  3/45 [websocket-client]
#    -- -------------------------------------  3/45 [websocket-client]
#    -- -------------------------------------  3/45 [websocket-client]
#    -- -------------------------------------  3/45 [websocket-client]
#    -- -------------------------------------  3/45 [websocket-client]
#    -- -------------------------------------  3/45 [websocket-client]
#    --- ------------------------------------  4/45 [webcolors]
#    --- ------------------------------------  4/45 [webcolors]
#    ---- -----------------------------------  5/45 [uri-template]
#    ----- ----------------------------------  6/45 [tinycss2]
#    ----- ----------------------------------  6/45 [tinycss2]
#    ------ ---------------------------------  7/45 [send2trash]
#    ------ ---------------------------------  7/45 [send2trash]
#    ------ ---------------------------------  7/45 [send2trash]
#    ------- --------------------------------  8/45 [rfc3986-validator]
#    -------- ------------------------------- 10/45 [pywinpty]
#    --------- ------------------------------ 11/45 [python-json-logger]
#    --------- ------------------------------ 11/45 [python-json-logger]
#    ---------- ----------------------------- 12/45 [prometheus-client]
#    ---------- ----------------------------- 12/45 [prometheus-client]
#    ---------- ----------------------------- 12/45 [prometheus-client]
#    ---------- ----------------------------- 12/45 [prometheus-client]
#    ---------- ----------------------------- 12/45 [prometheus-client]
#    ---------- ----------------------------- 12/45 [prometheus-client]
#    ----------- ---------------------------- 13/45 [pandocfilters]
#    ------------ --------------------------- 14/45 [mistune]
#    ------------ --------------------------- 14/45 [mistune]
#    ------------ --------------------------- 14/45 [mistune]
#    ------------ --------------------------- 14/45 [mistune]
#    ------------ --------------------------- 14/45 [mistune]
#    ------------ --------------------------- 14/45 [mistune]
#    ------------ --------------------------- 14/45 [mistune]
#    ------------ --------------------------- 14/45 [mistune]
#    ------------- -------------------------- 15/45 [lark]
#    ------------- -------------------------- 15/45 [lark]
#    ------------- -------------------------- 15/45 [lark]
#    ------------- -------------------------- 15/45 [lark]
#    ------------- -------------------------- 15/45 [lark]
#    -------------- ------------------------- 16/45 [jupyterlab_widgets]
#    --------------- ------------------------ 17/45 [jupyterlab-pygments]
#    ---------------- ----------------------- 18/45 [json5]
#    ---------------- ----------------------- 18/45 [json5]
#    ---------------- ----------------------- 19/45 [fqdn]
#    ----------------- ---------------------- 20/45 [defusedxml]
#    ----------------- ---------------------- 20/45 [defusedxml]
#    ----------------- ---------------------- 20/45 [defusedxml]
#    ------------------ --------------------- 21/45 [bleach]
#    ------------------ --------------------- 21/45 [bleach]
#    ------------------ --------------------- 21/45 [bleach]
#    ------------------ --------------------- 21/45 [bleach]
#    ------------------ --------------------- 21/45 [bleach]
#    ------------------ --------------------- 21/45 [bleach]
#    ------------------ --------------------- 21/45 [bleach]
#    ------------------ --------------------- 21/45 [bleach]
#    ------------------ --------------------- 21/45 [bleach]
#    ------------------ --------------------- 21/45 [bleach]
#    ------------------ --------------------- 21/45 [bleach]
#    ------------------- -------------------- 22/45 [babel]
#    ------------------- -------------------- 22/45 [babel]
#    ------------------- -------------------- 22/45 [babel]
#    ------------------- -------------------- 22/45 [babel]
#    ------------------- -------------------- 22/45 [babel]
#    ------------------- -------------------- 22/45 [babel]
#    ------------------- -------------------- 22/45 [babel]
#    ------------------- -------------------- 22/45 [babel]
#    ------------------- -------------------- 22/45 [babel]
#    ------------------- -------------------- 22/45 [babel]
#    ------------------- -------------------- 22/45 [babel]
#    ------------------- -------------------- 22/45 [babel]
#    ------------------- -------------------- 22/45 [babel]
#    ------------------- -------------------- 22/45 [babel]
#    ------------------- -------------------- 22/45 [babel]
#    ------------------- -------------------- 22/45 [babel]
#    ------------------- -------------------- 22/45 [babel]
#    ------------------- -------------------- 22/45 [babel]
#    ------------------- -------------------- 22/45 [babel]
#    ------------------- -------------------- 22/45 [babel]
#    ------------------- -------------------- 22/45 [babel]
#    ------------------- -------------------- 22/45 [babel]
#    ------------------- -------------------- 22/45 [babel]
#    ------------------- -------------------- 22/45 [babel]
#    -------------------- ------------------- 23/45 [async-lru]
#    --------------------- ------------------ 24/45 [terminado]
#    ----------------------- ---------------- 26/45 [jupyter-builder]
#    ----------------------- ---------------- 26/45 [jupyter-builder]
#    ----------------------- ---------------- 26/45 [jupyter-builder]
#    ----------------------- ---------------- 26/45 [jupyter-builder]
#    ------------------------ --------------- 27/45 [arrow]
#    ------------------------ --------------- 27/45 [arrow]
#    ------------------------ --------------- 27/45 [arrow]
#    ------------------------ --------------- 28/45 [argon2-cffi-bindings]
#    ------------------------- -------------- 29/45 [jupyter-server-terminals]
#    -------------------------- ------------- 30/45 [isoduration]
#    -------------------------- ------------- 30/45 [isoduration]
#    --------------------------- ------------ 31/45 [ipywidgets]
#    --------------------------- ------------ 31/45 [ipywidgets]
#    --------------------------- ------------ 31/45 [ipywidgets]
#    --------------------------- ------------ 31/45 [ipywidgets]
#    --------------------------- ------------ 31/45 [ipywidgets]
#    --------------------------- ------------ 31/45 [ipywidgets]
#    --------------------------- ------------ 31/45 [ipywidgets]
#    --------------------------- ------------ 31/45 [ipywidgets]
#    ---------------------------- ----------- 32/45 [argon2-cffi]
#    ---------------------------- ----------- 32/45 [argon2-cffi]
#    ----------------------------- ---------- 33/45 [nbformat]
#    ----------------------------- ---------- 33/45 [nbformat]
#    ----------------------------- ---------- 33/45 [nbformat]
#    ----------------------------- ---------- 33/45 [nbformat]
#    ----------------------------- ---------- 33/45 [nbformat]
#    ----------------------------- ---------- 33/45 [nbformat]
#    ----------------------------- ---------- 33/45 [nbformat]
#    ------------------------------ --------- 34/45 [jupyter-console]
#    ------------------------------ --------- 34/45 [jupyter-console]
#    ------------------------------- -------- 35/45 [nbclient]
#    ------------------------------- -------- 35/45 [nbclient]
#    -------------------------------- ------- 36/45 [jupyter-events]
#    -------------------------------- ------- 37/45 [nbconvert]
#    -------------------------------- ------- 37/45 [nbconvert]
#    -------------------------------- ------- 37/45 [nbconvert]
#    -------------------------------- ------- 37/45 [nbconvert]
#    -------------------------------- ------- 37/45 [nbconvert]
#    -------------------------------- ------- 37/45 [nbconvert]
#    -------------------------------- ------- 37/45 [nbconvert]
#    -------------------------------- ------- 37/45 [nbconvert]
#    -------------------------------- ------- 37/45 [nbconvert]
#    --------------------------------- ------ 38/45 [jupyter-server]
#    --------------------------------- ------ 38/45 [jupyter-server]
#    --------------------------------- ------ 38/45 [jupyter-server]
#    --------------------------------- ------ 38/45 [jupyter-server]
#    --------------------------------- ------ 38/45 [jupyter-server]
#    --------------------------------- ------ 38/45 [jupyter-server]
#    --------------------------------- ------ 38/45 [jupyter-server]
#    --------------------------------- ------ 38/45 [jupyter-server]
#    --------------------------------- ------ 38/45 [jupyter-server]
#    --------------------------------- ------ 38/45 [jupyter-server]
#    ----------------------------------- ---- 40/45 [jupyterlab-server]
#    ----------------------------------- ---- 40/45 [jupyterlab-server]
#    ----------------------------------- ---- 40/45 [jupyterlab-server]
#    ------------------------------------ --- 41/45 [jupyter-lsp]
#    ------------------------------------ --- 41/45 [jupyter-lsp]
#    ------------------------------------ --- 41/45 [jupyter-lsp]
#    ------------------------------------ --- 41/45 [jupyter-lsp]
#    ------------------------------------- -- 42/45 [jupyterlab]
#    ------------------------------------- -- 42/45 [jupyterlab]
#    ------------------------------------- -- 42/45 [jupyterlab]
#    ------------------------------------- -- 42/45 [jupyterlab]
#    ------------------------------------- -- 42/45 [jupyterlab]
#    ------------------------------------- -- 42/45 [jupyterlab]
#    ------------------------------------- -- 42/45 [jupyterlab]
#    ------------------------------------- -- 42/45 [jupyterlab]
#    ------------------------------------- -- 42/45 [jupyterlab]
#    ------------------------------------- -- 42/45 [jupyterlab]
#    ------------------------------------- -- 42/45 [jupyterlab]
#    ------------------------------------- -- 42/45 [jupyterlab]
#    ------------------------------------- -- 42/45 [jupyterlab]
#    ------------------------------------- -- 42/45 [jupyterlab]
#    ------------------------------------- -- 42/45 [jupyterlab]
#    ------------------------------------- -- 42/45 [jupyterlab]
#    -------------------------------------- - 43/45 [notebook]
#    -------------------------------------- - 43/45 [notebook]
#    -------------------------------------- - 43/45 [notebook]
#    -------------------------------------- - 43/45 [notebook]
#    ---------------------------------------  44/45 [jupyter]
#    ---------------------------------------- 45/45 [jupyter]
#
# Successfully installed argon2-cffi-25.1.0 argon2-cffi-bindings-25.1.0 arrow-1.4.0 async-lru-2.3.0 babel-2.18.0 bleach-6.4.0 defusedxml-0.7.1 fastjsonschema-2.21.2 fqdn-1.5.1 ipywidgets-8.1.8 isoduration-20.11.0 json5-0.15.0 jupyter-1.1.1 jupyter-builder-1.0.2 jupyter-console-6.6.3 jupyter-events-0.12.1 jupyter-lsp-2.3.1 jupyter-server-2.20.0 jupyter-server-terminals-0.5.4 jupyterlab-4.6.1 jupyterlab-pygments-0.3.0 jupyterlab-server-2.28.0 jupyterlab_widgets-3.0.16 lark-1.3.1 mistune-3.3.2 nbclient-0.11.0 nbconvert-7.17.1 nbformat-5.10.4 notebook-7.6.0 notebook-shim-0.2.4 pandocfilters-1.5.1 prometheus-client-0.25.0 python-json-logger-4.1.0 pywinpty-3.0.5 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rfc3987-syntax-1.1.0 send2trash-2.1.0 terminado-0.18.1 tinycss2-1.5.1 uri-template-1.3.0 webcolors-25.10.0 webencodings-0.5.1 websocket-client-1.9.0 widgetsnbextension-4.0.15
# Note: you may need to restart the kernel to use updated packages.

# %%
import gradio as gr # oh yeah!

# %%
# Load environment variables in a file called .env
# Print the key prefixes to help with any debugging
# You can choose whichever providers you like - or all Ollama

load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")

if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:8]}")
else:
    print("Google API Key not set")

# %%
# Connect to OpenAI, Anthropic and Google; comment out the Claude or Google lines if you're not using them

openai = OpenAI()

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"

anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Connect to OpenAI, Anthropic and Google; comment out the Claude or Google lines if you're not using them
# ----> 3 openai = OpenAI()
#       5 anthropic_url = "https://api.anthropic.com/v1/"
#       6 gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
#
# NameError: name 'OpenAI' is not defined

# %%
# Let's wrap a call to GPT-4.1-mini in a simple function
from IPython.display import Markdown, display
openai = OpenAI(base_url='http://localhost:11434/v1',api_key='ollama')
system_message = "You are a helpful assistant"

def message_gpt(prompt):
    messages = [{"role": "system", "content": system_message}, {"role": "user", "content": prompt}]
    response = openai.chat.completions.create(model='llama3.2:1b', messages=messages)
    return response.choices[0].message.content

# %%
# This can reveal the "training cut off", or the most recent date in the training data

message_gpt("What is today's date?")
# Out:
# "However, I'm a large language model, I don't have real-time access to the current date. But I can suggest some ways for you to find out today's date.\n\nYou can try looking at your phone or computer's clock or calendar. If you're unsure about how to do this, please let me know, and I'll be happy to help."

# %% [markdown]
# ## User Interface time!

# %%
# here's a simple function

def shout(text):
    print(f"Shout has been called with input {text}")
    return text.upper()

# %%
shout("hello")
# Out:
# Shout has been called with input hello
# 'HELLO'

# %%
gr.Interface(fn=shout, inputs="textbox", outputs="textbox", flagging_mode="never").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Shout has been called with input hi
# Shout has been called with input how are you ?

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">NOTE: Using Gradio's Share tool</h2>
#             <span style="color:#900;">I'm about to show you a really cool way to share your Gradio UI with others. This deploys your gradio app as a demo on gradio's website, and then allows gradio to call the 'shout' function. This uses an advanced technology known as 'HTTP tunneling' (like ngrok for people who know it) which isn't allowed by many Antivirus programs and corporate environments. If you get an error, just skip the next cell.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Adding share=True means that it can be accessed publically
# A more permanent hosting is available using a platform called Spaces from HuggingFace, which we will touch on next week
# NOTE: Some Anti-virus software and Corporate Firewalls might not like you using share=True.
# If you're at work on on a work network, I suggest skip this test.

gr.Interface(fn=shout, inputs="textbox", outputs="textbox", flagging_mode='never').launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * Running on public URL: https://78c8c01aac3e8f27de.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://78c8c01aac3e8f27de.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Shout has been called with input hi

# %%
# Adding inbrowser=True opens up a new browser window automatically

gr.Interface(fn=shout, inputs="textbox", outputs="textbox", flagging_mode="never").launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## Adding authentication
#
# Gradio makes it very easy to have userids and passwords
#
# Obviously if you use this, have it look properly in a secure place for passwords! At a minimum, use your .env

# %%
gr.Interface(fn=shout, inputs="textbox", outputs="textbox", flagging_mode="never").launch(inbrowser=True, auth=("ed", "bananas"))
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Shout has been called with input hi

# %% [markdown]
# ## Forcing dark mode
#
# Gradio appears in light mode or dark mode depending on the settings of the browser and computer. There is a way to force gradio to appear in dark mode, but Gradio recommends against this as it should be a user preference (particularly for accessibility reasons). But if you wish to force dark mode for your screens, below is how to do it.

# %%
# Define this variable and then pass js=force_dark_mode when creating the Interface

force_dark_mode = """
function refresh() {
    const url = new URL(window.location);
    if (url.searchParams.get('__theme') !== 'dark') {
        url.searchParams.set('__theme', 'dark');
        window.location.href = url.href;
    }
}
"""
gr.Interface(fn=shout, inputs="textbox", outputs="textbox", flagging_mode="never", js=force_dark_mode).launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7864
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7864/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# Adding a little more:

message_input = gr.Textbox(label="Your message:", info="Enter a message to be shouted", lines=7)
message_output = gr.Textbox(label="Response:", lines=8)

view = gr.Interface(
    fn=shout,
    title="Shout",
    inputs=[message_input],
    outputs=[message_output],
    examples=["hello", "howdy"],
    flagging_mode="never"
    )
view.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7865
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7865/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Shout has been called with input hi there
# Shout has been called with input howdy

# %%
# And now - changing the function from "shout" to "message_gpt"

message_input = gr.Textbox(label="Your message:", info="Enter a message for GPT-4.1-mini", lines=7)
message_output = gr.Textbox(label="Response:", lines=8)

view = gr.Interface(
    fn=message_gpt,
    title="GPT",
    inputs=[message_input],
    outputs=[message_output],
    examples=["hello", "howdy"],
    flagging_mode="never"
    )
view.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7870
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7870/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# Let's use Markdown
# Are you wondering why it makes any difference to set system_message when it's not referred to in the code below it?
# I'm taking advantage of system_message being a global variable, used back in the message_gpt function (go take a look)
# Not a great software engineering practice, but quite common during Jupyter Lab R&D!

system_message = "You are a helpful assistant that responds in markdown without code blocks"

message_input = gr.Textbox(label="Your message:", info="Enter a message for GPT-4.1-mini", lines=7)
message_output = gr.Markdown(label="Response:")

view = gr.Interface(
    fn=message_gpt,
    title="GPT",
    inputs=[message_input],
    outputs=[message_output],
    examples=[
        "Explain the Transformer architecture to a layperson",
        "Explain the Transformer architecture to an aspiring AI engineer",
        ],
    flagging_mode="never"
    )
view.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7866
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7866/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# Let's create a call that streams back results
# If you'd like a refresher on Generators (the "yield" keyword),
# Please take a look at the Intermediate Python guide in the guides folder
openai = OpenAI(base_url='http://localhost:11434/v1',api_key='ollama')
def stream_gpt(prompt):
    messages = [
        {"role": "system", "content": system_message},
        {"role": "user", "content": prompt}
      ]
    stream = openai.chat.completions.create(
        model='llama3.2:1b',
        messages=messages,
        stream=True
    )
    result = ""
    for chunk in stream:
        result += chunk.choices[0].delta.content or ""
        yield result

# %%
message_input = gr.Textbox(label="Your message:", info="Enter a message for GPT-4.1-mini", lines=7)
message_output = gr.Markdown(label="Response:")

view = gr.Interface(
    fn=stream_gpt,
    title="GPT",
    inputs=[message_input],
    outputs=[message_output],
    examples=[
        "Explain the Transformer architecture to a layperson",
        "Explain the Transformer architecture to an aspiring AI engineer",
        ],
    flagging_mode="never"
    )
view.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7867
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7867/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
def stream_claude(prompt):
    messages = [
        {"role": "system", "content": system_message},
        {"role": "user", "content": prompt}
      ]
    stream = anthropic.chat.completions.create(
        model='claude-sonnet-4-5-20250929',
        messages=messages,
        stream=True
    )
    result = ""
    for chunk in stream:
        result += chunk.choices[0].delta.content or ""
        yield result

# %%
message_input = gr.Textbox(label="Your message:", info="Enter a message for Claude 4.5 Sonnet", lines=7)
message_output = gr.Markdown(label="Response:")

view = gr.Interface(
    fn=stream_claude,
    title="Claude",
    inputs=[message_input],
    outputs=[message_output],
    examples=[
        "Explain the Transformer architecture to a layperson",
        "Explain the Transformer architecture to an aspiring AI engineer",
        ],
    flagging_mode="never"
    )
view.launch()

# %% [markdown]
# ## And now getting fancy
#
# Remember to check the Intermediate Python Guide if you're unsure about generators and "yield"

# %%
def stream_model(prompt, model):
    if model=="llama3.2:1b":
        result = stream_gpt(prompt)
    elif model=="Claude":
        result = stream_claude(prompt)
    else:
        raise ValueError("Unknown model")
    yield from result

# %%
message_input = gr.Textbox(label="Your message:", info="Enter a message for the LLM", lines=7)
model_selector = gr.Dropdown(["GPT", "Claude"], label="Select model", value="GPT")
message_output = gr.Markdown(label="Response:")

view = gr.Interface(
    fn=stream_model,
    title="LLMs",
    inputs=[message_input, model_selector],
    outputs=[message_output],
    examples=[
            ["Explain the Transformer architecture to a layperson", "llama3.2:1b"],
            ["Explain the Transformer architecture to an aspiring AI engineer", "Claude"]
        ],
    flagging_mode="never"
    )
view.launch()
# Out:
# c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv\Lib\site-packages\gradio\components\dropdown.py:230: UserWarning: The value passed into gr.Dropdown() is not in the list of choices. Please update the list of choices to include: llama3.2:1b or set allow_custom_value=True.
#   warnings.warn(
# * Running on local URL:  http://127.0.0.1:7868
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7868/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# # Building a company brochure generator
#
# Now you know how - it's simple!

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you read the next few cells</h2>
#             <span style="color:#900;">
#                 Try to do this yourself - go back to the company brochure in week1, day5 and add a Gradio UI to the end. Then come and look at the solution.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
from scraper import fetch_website_contents

# %%
# Again this is typical Experimental mindset - I'm changing the global variable we used above:

system_message = """
You are an assistant that analyzes the contents of a company website landing page
and creates a short brochure about the company for prospective customers, investors and recruits.
Respond in markdown without code blocks.
"""

# %%
def stream_brochure(company_name, url, model):
    yield ""
    prompt = f"Please generate a company brochure for {company_name}. Here is their landing page:\n"
    prompt += fetch_website_contents(url)

    if model=="llama3.2:1b":
        result = stream_gpt(prompt)
    elif model=="Claude":
        result = stream_claude(prompt)
    else:
        raise ValueError("Unknown model")
    yield from result

# %%
name_input = gr.Textbox(label="Company name:")
url_input = gr.Textbox(label="Landing page URL including http:// or https://")
model_selector = gr.Dropdown(["llama3.2:1b", "Claude"], label="Select model", value="llama3.2:1b")
message_output = gr.Markdown(label="Response:")

view = gr.Interface(
    fn=stream_brochure,
    title="Brochure Generator",
    inputs=[name_input, url_input, model_selector],
    outputs=[message_output],
    examples=[
            ["hugging face", "https://huggingface.co", "llama3.2:1b"],
            ["Edward Donner", "https://edwarddonner.com", "Claude"]
        ],
    flagging_mode="never"
    )
view.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7869
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7869/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Gradio Resources</h2>
#             <span style="color:#f71;">If you'd like to go deeper on Gradio, check out the amazing documentation - a wonderful rabbit hole.<br/>
#             <a href="https://www.gradio.app/guides/quickstart">https://www.gradio.app/guides/quickstart</a><br/>Gradio is primarily designed for Demos, Prototypes and MVPs, but I've also used it frequently to make internal apps for power users.
#             </span>
#         </td>
#     </tr>
# </table>
