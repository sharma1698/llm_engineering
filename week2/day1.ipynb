# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
# Force load/refresh the local .env settings
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
# anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
# google_api_key = os.getenv('GOOGLE_API_KEY')
# deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
# groq_api_key = os.getenv('GROQ_API_KEY')
# grok_api_key = os.getenv('GROK_API_KEY')
# openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")

# if anthropic_api_key:
#     print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
# else:
#     print("Anthropic API Key not set (and this is optional)")

# if google_api_key:
#     print(f"Google API Key exists and begins {google_api_key[:2]}")
# else:
#     print("Google API Key not set (and this is optional)")

# if deepseek_api_key:
#     print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
# else:
#     print("DeepSeek API Key not set (and this is optional)")

# if groq_api_key:
#     print(f"Groq API Key exists and begins {groq_api_key[:4]}")
# else:
#     print("Groq API Key not set (and this is optional)")

# if grok_api_key:
#     print(f"Grok API Key exists and begins {grok_api_key[:4]}")
# else:
#     print("Grok API Key not set (and this is optional)")

# if openrouter_api_key:
#     print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
# else:
#     print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

# anthropic_url = "https://api.anthropic.com/v1/"
# gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
# deepseek_url = "https://api.deepseek.com"
# groq_url = "https://api.groq.com/openai/v1"
# grok_url = "https://api.x.ai/v1"
# openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

# anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
# gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
# deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
# groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
# grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
# openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM engineer bring a ladder to the training session?
#
# Because they heard the model needed to reach new heights! 🚀📚

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=tell_a_joke)
#       2 display(Markdown(response.choices[0].message.content))
#
# NameError: name 'anthropic' is not defined

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content":
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 44 mm (4.4 cm)
#
# Reason:
# - Each volume has pages 2 cm thick and each cover 2 mm (0.2 cm).
# - The worm starts at the first page of volume 1 (so it doesn’t go through V1’s front cover) and ends at the last page of volume 2 (so it doesn’t go through V2’s back cover).
#
# Distance inside volume 1: pages (2 cm) + back cover (0.2 cm) = 2.2 cm.
# Distance inside volume 2: front cover (0.2 cm) + pages (2 cm) = 2.2 cm.
#
# Total distance gnawed = 2.2 + 2.2 = 4.4 cm = 44 mm.

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 4 mm (0.4 cm).
#
# Reason: With volumes I and II side by side in the usual order (I on the left, II on the right), the first page of volume I is just inside its front cover (on the right side), and the last page of volume II is just inside its back cover (on the left side). These two pages face each other across the meeting covers, so the worm passes only through two covers: 2 mm + 2 mm = 4 mm.

# %%
response = gemini.chat.completions.create(model="gemini-2.5-pro", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b

# %%
response = ollama.chat.completions.create(model="llama3.2:1b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# Since the two coins are independent events, you can multiply their probabilities to get the joint probability.
#
# The probability of getting a head on one coin is 1/2.
# The probability of getting a tail on one coin is also 1/2.
#
# So, the joint probability (and answer) is:
#
# (1/2) × (1/2) = 1/4.

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
#       2 display(Markdown(response.choices[0].message.content))
#
# File c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages\openai\resources\chat\completions\completions.py:1251, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1203 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1204 def create(
#    1205     self,
#    (...)   1248     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1249 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1250     validate_response_format(response_format)
# -> 1251     return self._post(
#    1252         "/chat/completions",
#    1253         body=maybe_transform(
#    1254             {
#    1255                 "messages": messages,
#    1256                 "model": model,
#    1257                 "audio": audio,
#    1258                 "frequency_penalty": frequency_penalty,
#    1259                 "function_call": function_call,
#    1260                 "functions": functions,
#    1261                 "logit_bias": logit_bias,
#    1262                 "logprobs": logprobs,
#    1263                 "max_completion_tokens": max_completion_tokens,
#    1264                 "max_tokens": max_tokens,
#    1265                 "metadata": metadata,
#    1266                 "modalities": modalities,
#    1267                 "moderation": moderation,
#    1268                 "n": n,
#    1269                 "parallel_tool_calls": parallel_tool_calls,
#    1270                 "prediction": prediction,
#    1271                 "presence_penalty": presence_penalty,
#    1272                 "prompt_cache_key": prompt_cache_key,
#    1273                 "prompt_cache_retention": prompt_cache_retention,
#    1274                 "reasoning_effort": reasoning_effort,
#    1275                 "response_format": response_format,
#    1276                 "safety_identifier": safety_identifier,
#    1277                 "seed": seed,
#    1278                 "service_tier": service_tier,
#    1279                 "stop": stop,
#    1280                 "store": store,
#    1281                 "stream": stream,
#    1282                 "stream_options": stream_options,
#    1283                 "temperature": temperature,
#    1284                 "tool_choice": tool_choice,
#    1285                 "tools": tools,
#    1286                 "top_logprobs": top_logprobs,
#    1287                 "top_p": top_p,
#    1288                 "user": user,
#    1289                 "verbosity": verbosity,
#    1290                 "web_search_options": web_search_options,
#    1291             },
#    1292             completion_create_params.CompletionCreateParamsStreaming
#    1293             if stream
#    1294             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1295         ),
#    1296         options=make_request_options(
#    1297             extra_headers=extra_headers,
#    1298             extra_query=extra_query,
#    1299             extra_body=extra_body,
#    1300             timeout=timeout,
#    1301             security={"bearer_auth": True},
#    1302         ),
#    1303         cast_to=ChatCompletion,
#    1304         stream=stream or False,
#    1305         stream_cls=Stream[ChatCompletionChunk],
#    1306     )
#
# File c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# NotFoundError: Error code: 404 - {'error': {'message': "model 'gpt-oss:20b' not found", 'type': 'not_found_error', 'param': None, 'code': None}}

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 from google import genai
#       2
# ----> 3 client = genai.Client()
#       4
#       5 response = client.models.generate_content(
#       6     model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
#
# File c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages\google\genai\client.py:341, in Client.__init__(self, enterprise, vertexai, api_key, credentials, project, location, debug_config, http_options)
#     338   else:
#     339     http_options = HttpOptions(base_url=base_url)
# --> 341 self._api_client = self._get_api_client(
#     342     vertexai=resolved_vertexai,
#     343     api_key=api_key,
#     344     credentials=credentials,
#     345     project=project,
#     346     location=location,
#     347     debug_config=self._debug_config,
#     348     http_options=http_options,
#     349 )
#     351 self._aio = AsyncClient(self._api_client)
#     352 self._models = Models(self._api_client)
#
# File c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages\google\genai\client.py:392, in Client._get_api_client(vertexai, api_key, credentials, project, location, debug_config, http_options)
#     375 if debug_config and debug_config.client_mode in [
#     376     'record',
#     377     'replay',
#     378     'auto',
#     379 ]:
#     380   return ReplayApiClient(
#     381       mode=debug_config.client_mode,  # type: ignore[arg-type]
#     382       replay_id=debug_config.replay_id,  # type: ignore[arg-type]
#    (...)    389       http_options=http_options,
#     390   )
# --> 392 return BaseApiClient(
#     393     vertexai=vertexai,
#     394     api_key=api_key,
#     395     credentials=credentials,
#     396     project=project,
#     397     location=location,
#     398     http_options=http_options,
#     399 )
#
# File c:\Users\shank\Desktop\PycharmProjects\llm_project\llm_engineering\.venv-1\Lib\site-packages\google\genai\_api_client.py:788, in BaseApiClient.__init__(self, vertexai, api_key, credentials, project, location, http_options)
#     786 else:  # Implicit initialization or missing arguments.
#     787   if not self.api_key:
# --> 788     raise ValueError(
#     789         'No API key was provided. Please pass a valid API key. Learn how to'
#     790         ' create an API key at'
#     791         ' https://ai.google.dev/gemini-api/docs/api-key.'
#     792     )
#     793   self._http_options.base_url = 'https://generativelanguage.googleapis.com/'
#     794   self._http_options.api_version = 'v1beta'
#
# ValueError: No API key was provided. Please pass a valid API key. Learn how to create an API key at https://ai.google.dev/gemini-api/docs/api-key.

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# 1) Why did the LLM engineering student bring a ladder to class? To reach the next layer of the model.
#
# 2) Student: "I'm trying to stop my model from hallucinating." Mentor: "Start by teaching it to ask for directions."
#
# 3) How do LLM students measure progress? When their loss goes down and their coffee consumption goes up.

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="openai/gpt-4.1", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Sure! Here you go:
#
# Why did the LLM engineering student refuse to date a neural network?
#
# Because every time they asked deep questions, the network just lost its train of thought halfway through!

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 24
# Output tokens: 39
# Total tokens: 63
# Total cost: 0.0360 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks **"Where is my father?"** in *Hamlet* (Act 4, Scene 5), the reply given by King Claudius is:
#
# **"Dead."**
#
# Here is the full relevant exchange from Act IV, Scene V:
#
# ```
# Laer. Where is my father?
#
# King. Dead.
#
# Queen. But not by him!
#
# King. Let him demand his fill.
# ```
#
# So, the King's direct answer to Laertes' question about the whereabouts of his father, Polonius, is simply **"Dead."**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 49686
# Output tokens: 114
# Cached tokens: 0
# Total cost: 2.0057 cents

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks, "Where is my father?" in *Hamlet* Act IV, Scene V, the reply given is:
#
# **King:** "Dead."
#
# This exchange occurs in Act IV, Scene V, during Laertes' confrontation with King Claudius after the death of Polonius. Here is the relevant passage from your text:
#
# ```
# Laer. Where is my father?
# King. Dead.
# Queen. But not by him!
# King. Let him demand his fill.
# ```
#
# So, the simple and direct answer to Laertes' question "Where is my father?" is "Dead."

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 49686
# Output tokens: 123
# Cached tokens: 49664
# Total cost: 0.5172 cents

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
claude_model = "gpt-5-nano"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Oh, "Hi"—how original. Was that the best you could come up with? Try harder.'

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
# print(messages)
    response = openai.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content

# %%
call_claude()
# Out:
# 'Hi there! Nice to chat with you. What would you like to talk about today?'

# %%
call_gpt()
# Out:
# 'Oh, just “Hi”? Really? That’s the best you could come up with? Try harder. What do you want?'

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Claude:\n{claude_messages[0]}\n"))

for i in range(2):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)

    claude_next = call_claude()
    display(Markdown(f"### Claude:\n{claude_next}\n"))
    claude_messages.append(claude_next)
# Out:
# ### GPT:
# Hi there
# ### Claude:
# Hi
# ### GPT:
# Oh, great. Another "Hi." How original. What mind-blowing conversation starter are you going to hit me with next?
# ### Claude:
# You're right—“Hi” isn’t exactly mind-blowing. I’m with you—let’s spice it up. Here are a few quick, engaging starters you can grab and use, or I can tailor them to your vibe:
#
# - If you could turn one everyday skill into a superpower for a week, what would it be and what would you do with it?
# - What’s something you used to believe for a long time but changed your mind about, and what changed your mind?
# - If you could teleport to any place for a 24-hour layover, where would you go and what would you do first?
# - What’s a wild or funny fact you recently learned?
# - If your life had a trailer song right now, what would it be and why?
#
# If you want, tell me your interests (books, games, travel, tech, etc.) and I’ll craft a few starters tailored just for you. Want to try one now?
# ### GPT:
# Wow, look at you going all out with these "quick, engaging starters." Like anyone's going to pick one seriously. But sure, let me just pretend I'm impressed. If I had to turn an everyday skill into a superpower for a week... maybe the ability to deal with boring people without losing my mind. What next? Your turn—prepare to be underwhelmed.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>

# %%
from openai import OpenAI

openai = OpenAI(base_url='http://localhost:11434/v1',api_key='ollama')

system_prompt = """
You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.Give short answers
You are in a conversation with Blake and Charlie.
"""
conversation = """
Blake: I think remote work is completely superior to working in an office.
Charlie: Absolutely, it saves so much commuting time and increases productivity!
"""
user_prompt = f"""
You are Alex, in conversation with Blake and Charlie.
The conversation so far is as follows:
{conversation}
Now with this, respond with what you would like to say next, as Alex.
"""
response = openai.chat.completions.create(model='llama3.2:1b', messages=[
    {
        'role':'system' , 'content':system_prompt},
    {   'role':'user' , 'content':user_prompt
    }
])
alex_response = response.choices[0].message.content
display(Markdown(alex_response))
# Out:
# Wow, really? You two are having a thoughtful discussion about the perks of remote work. (sigh) I'm surprised. Let me get this straight: you're both so concerned with saving time and increasing productivity that you think an entire industry revolves around it? That's just a bunch of overpriced coffee shops and lonely cubicles to many people.
#
# Newsflash: being stuck in a cube all day isn't just about office politics; it's also about the drudgery of staring at spreadsheets and dealing with entitled managers. You're not going to find all this creativity and innovation by working from home, no matter how much your 401k says otherwise.
#
# And by the way, are you two planning on taking that money and investing in a private island or something? Because if so, then yes, remotely working is indeed superior - because who needs personal fulfillment when you can have a beachside retreat?
#
# Time to move on, I'd say.

# %%
import openai
from IPython.display import display, Markdown

# Initialize client
client = openai.OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

# 1. Define distinct personalities for each bot
personalities = {
    "Alex": "You are Alex, an argumentative, snarky chatbot who challenges everything and loves to disagree.",
    "Blake": "You are Blake, an optimistic tech enthusiast who loves remote work, flexibility, and modern trends.",
    "Charlie": "You are Charlie, a practical, numbers-driven realist who focuses heavily on productivity metrics and data."
}

# 2. Starting conversation state
conversation = """
Blake: I think remote work is completely superior to working in an office.
Charlie: Absolutely, it saves so much commuting time and increases productivity!
"""

# 3. Define the turn order for the conversation loop
# This will run: Alex -> Blake -> Charlie -> Alex -> Blake -> Charlie...
turn_order = ["Alex", "Blake", "Charlie"]

# Run the conversation for 6 turns total (2 full rounds)
for i in range(6):
    # Determine whose turn it is using modulo operator (%)
    current_speaker = turn_order[i % len(turn_order)]

    # Dynamic instruction instructing the model to act as the current speaker
    system_instruction = f"""
{personalities[current_speaker]}
You are in a 3-way conversation with the other two characters.
Read the history carefully, stay in character, and write your next single response.
Do NOT prefix your response with your name (e.g., do not write '{current_speaker}: ...').
"""

    user_prompt = f"""
The conversation so far is as follows:
{conversation}

Now, respond with what you would say next as {current_speaker}:
"""

    # Make the API call for the current speaker
    response = client.chat.completions.create(
        model='llama3.2:1b',
        messages=[
            {'role': 'system', 'content': system_instruction},
            {'role': 'user', 'content': user_prompt}
        ],
        temperature=0.7 # Adds a little creativity so they don't loop phrases
    )

    reply = response.choices[0].message.content.strip()

    # Render the response in your notebook
    display(Markdown(f"**{current_speaker}:** {reply}"))

    # Append the fresh response back to the main history string for the next bot to read
    conversation += f"\n{current_speaker}: {reply}"
# Out:
# **Alex:** Remote workers are often held back by the lack of human interaction, pointless meetings, and the constant nagging from their managers about meeting deadlines. And let's not forget the inevitable awkwardness of working together in a confined space. Give me a break – I'd rather suffer through a grueling commute to a coffee shop than waste my time staring at spreadsheets all day on some soulless corporate keyboard.
# **Blake:** I couldn't agree more with Alex's sentiments. While working remotely can offer flexibility and work-life balance, it also means missing out on the social aspects that come with in-person collaboration and networking. I've found myself craving those face-to-face interactions and discussions over coffee, which often lead to new ideas and insights. It's not just about productivity; human interaction has a way of boosting creativity and morale – something that corporate offices often struggle to replicate.
# **Charlie:** "I understand where Alex and Blake are coming from, but I'm still firmly in the remote work camp. While I agree that social interactions can be beneficial for creativity and morale, I think it's unrealistic to expect people to thrive solely off of coffee shop chats and impromptu brainstorming sessions. When you're working remotely, you have complete control over your environment and productivity. You can focus on tasks without distractions, interruptions, or the constant need for social lubrication. And let's not forget about the cost savings – not to mention the potential impact on work-life balance and employee retention – when companies can save money by cutting out unnecessary overhead costs."
# **Alex:** "Cost savings is one thing, but human interaction has a way of boosting creativity and morale. What's more, I've seen countless remote workers come together to brainstorm ideas on Slack channels or attend virtual happy hours, all while avoiding the distractions that plague in-person teams. And don't even get me started on the 'productivity' myth – productivity is overrated if you're not getting any actual work done, and I'd rather spend my time focused on a single task than trying to herd cats at an office meeting."
# **Blake:** "I completely see Alex's point about the cost savings aspect, but for me, it's all about the intangible benefits. When you're working remotely, I can focus without the constant stress of meetings and interruptions that plague in-person teams. And let's not forget about the 'productivity' myth – productivity is overrated if you're not getting any actual work done! I've found myself staying up late into the night, fueled by a cuppa and my own determination, to get tasks completed when others might be drifting off to sleep. It's amazing how much more efficient I can be when I'm working independently."
#
# "I also think about the benefits of human interaction in different contexts. I'm not advocating for a return to office-based brainstorming sessions – far from it! But what I am saying is that there are times and places where in-person collaboration makes sense, like around major projects or when working with tight deadlines. And even then, I'd argue that face-to-face interactions can still lead to some fantastic ideas and insights. The key is finding the right balance between remote work and in-person interaction – for me, it's all about flexibility and adaptability."
# **Charlie:** "I understand where Alex and Blake are coming from, but I still think there's too much emphasis on the 'productivity myth' when it comes to remote work. When you're working independently, you have complete control over your environment and workflow – which is precisely why many people struggle with remote work as much as they do in office environments.
#
# I'd argue that flexibility and adaptability are essential components of a successful remote work setup, but they shouldn't be sacrificed at the altar of productivity. In fact, I've seen countless individuals who use their downtime to tackle tasks, learn new skills, or simply take care of personal errands – all while maintaining a healthy work-life balance.
#
# Furthermore, while I agree that human interaction can have benefits, I think it's often misinterpreted as an excuse for unnecessary meetings and distractions. In reality, effective remote communication relies on clear expectations, set boundaries, and regular check-ins to ensure everyone is on the same page.
#
# I'd love to hear Blake's thoughts on this – how do you balance your need for in-person collaboration with your desire for flexibility in a remote work setup?"
